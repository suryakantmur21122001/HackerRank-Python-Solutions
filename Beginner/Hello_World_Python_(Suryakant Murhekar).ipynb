# %% [markdown]
# # **Name - Suryakant Murhekar**

# %% [markdown]
# # **Problem: Say "Hello, World!" with Python**
# ## **Task:** Print the string "Hello, World!" to stdout.
# ## **Platform:** HackerRank

# %%
print("Hello, World!")
# Out:
# Hello, World!
